# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv('intermediate_files\sarcasm_headlines_cleaned.csv')
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#                                     headline_cleaned  num_changes
# 0  former versace store clerk sues over secret bl...            1
# 1  the roseanne revival catches up to our thorny ...            1
# 2  mom starting to fear sons web series closest t...            1
# 3  boehner just wants wife to listen not come up ...            1
# 4  jk rowling wishes snape happy birthday in the ...            1

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Lemmatize df 
df['lemmatized_headline'] = df['headline_cleaned'].apply(lambda x: ' '.join([token.lemma_ for token in nlp(x)]))
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#                                     headline_cleaned  num_changes  \
# 0  former versace store clerk sues over secret bl...            1
# 1  the roseanne revival catches up to our thorny ...            1
# 2  mom starting to fear sons web series closest t...            1
# 3  boehner just wants wife to listen not come up ...            1
# 4  jk rowling wishes snape happy birthday in the ...            1
#
#                                  lemmatized_headline
# 0  former versace store clerk sue over secret bla...
# 1  the roseanne revival catch up to our thorny po...
# 2  mom start to fear son web series close thing s...
# 3  boehner just want wife to listen not come up w...
# 4  jk rowling wish snape happy birthday in the mo...

# %%
# Part of Speech Tagging
df['pos_tags'] = df['headline_cleaned'].apply(lambda x: [(token.text, token.pos_) for token in nlp(x)])
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#                                     headline_cleaned  num_changes  \
# 0  former versace store clerk sues over secret bl...            1
# 1  the roseanne revival catches up to our thorny ...            1
# 2  mom starting to fear sons web series closest t...            1
# 3  boehner just wants wife to listen not come up ...            1
# 4  jk rowling wishes snape happy birthday in the ...            1
#
#                                  lemmatized_headline  \
# 0  former versace store clerk sue over secret bla...
# 1  the roseanne revival catch up to our thorny po...
# 2  mom start to fear son web series close thing s...
# 3  boehner just want wife to listen not come up w...
# 4  jk rowling wish snape happy birthday in the mo...
#
#                                             pos_tags
# 0  [(former, ADJ), (versace, NOUN), (store, NOUN)...
# 1  [(the, DET), (roseanne, PROPN), (revival, PROP...
# 2  [(mom, NOUN), (starting, VERB), (to, PART), (f...
# 3  [(boehner, NOUN), (just, ADV), (wants, VERB), ...
# 4  [(jk, PROPN), (rowling, PROPN), (wishes, VERB)...

# %%
# Stop word removal
df['stopwords_removed'] = df['headline_cleaned'].apply(lambda x: ' '.join([token.text for token in nlp(x) if not token.is_stop]))
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#                                     headline_cleaned  num_changes  \
# 0  former versace store clerk sues over secret bl...            1
# 1  the roseanne revival catches up to our thorny ...            1
# 2  mom starting to fear sons web series closest t...            1
# 3  boehner just wants wife to listen not come up ...            1
# 4  jk rowling wishes snape happy birthday in the ...            1
#
#                                  lemmatized_headline  \
# 0  former versace store clerk sue over secret bla...
# 1  the roseanne revival catch up to our thorny po...
# 2  mom start to fear son web series close thing s...
# 3  boehner just want wife to listen not come up w...
# 4  jk rowling wish snape happy birthday in the mo...
#
#                                             pos_tags  \
# 0  [(former, ADJ), (versace, NOUN), (store, NOUN)...
# 1  [(the, DET), (roseanne, PROPN), (revival, PROP...
# 2  [(mom, NOUN), (starting, VERB), (to, PART), (f...
# 3  [(boehner, NOUN), (just, ADV), (wants, VERB), ...
# 4  [(jk, PROPN), (rowling, PROPN), (wishes, VERB)...
#
#                                    stopwords_removed
# 0  versace store clerk sues secret black code min...
# 1  roseanne revival catches thorny political mood...
# 2  mom starting fear sons web series closest thin...
# 3  boehner wants wife listen come alternative deb...
# 4  jk rowling wishes snape happy birthday magical...

# %%
# BPE Tokenization
from tokenizers import Tokenizer, models, trainers, pre_tokenizers

overall_corpus = ' '.join(df['headline_cleaned'])
# Initialize a BPE tokenizer
tokenizer = Tokenizer(models.BPE())

# Set pre-tokenization rules (whitespace-based)
tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()

# Train the tokenizer on the corpus
trainer = trainers.BpeTrainer(vocab_size=1000, min_frequency=2, special_tokens=["<unk>", "<pad>", "<s>", "</s>"])
tokenizer.train_from_iterator([overall_corpus], trainer)

# Tokenize each headline
df['bpe_tokens'] = df['headline_cleaned'].apply(lambda x: tokenizer.encode(x).tokens)

# %%
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#                                     headline_cleaned  num_changes  \
# 0  former versace store clerk sues over secret bl...            1
# 1  the roseanne revival catches up to our thorny ...            1
# 2  mom starting to fear sons web series closest t...            1
# 3  boehner just wants wife to listen not come up ...            1
# 4  jk rowling wishes snape happy birthday in the ...            1
#
#                                  lemmatized_headline  \
# 0  former versace store clerk sue over secret bla...
# 1  the roseanne revival catch up to our thorny po...
# 2  mom start to fear son web series close thing s...
# 3  boehner just want wife to listen not come up w...
# 4  jk rowling wish snape happy birthday in the mo...
#
#                                             pos_tags  \
# 0  [('former', 'ADJ'), ('versace', 'NOUN'), ('sto...
# 1  [('the', 'DET'), ('roseanne', 'PROPN'), ('revi...
# 2  [('mom', 'NOUN'), ('starting', 'VERB'), ('to',...
# 3  [('boehner', 'NOUN'), ('just', 'ADV'), ('wants...
# 4  [('jk', 'PROPN'), ('rowling', 'PROPN'), ('wish...
#
#                                    stopwords_removed  \
# 0  versace store clerk sues secret black code min...
# 1  roseanne revival catches thorny political mood...
# 2  mom starting fear sons web series closest thin...
# 3  boehner wants wife listen come alternative deb...
# 4  jk rowling wishes snape happy birthday magical...
#
#                                           bpe_tokens
# 0  [for, mer, vers, ace, st, ore, cl, er, k, su, ...
# 1  [the, ro, se, an, ne, re, v, iv, al, cat, ch, ...
# 2  [mom, start, ing, to, fe, ar, s, ons, we, b, s...
# 3  [bo, e, h, ner, just, wants, wi, fe, to, list,...
# 4  [j, k, r, ow, ling, w, ish, es, sn, ap, e, hap...

# %%
df.to_csv('intermediate_files/spacy_preprocessing.csv', index=False)
